# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_detail1 = pd.read_csv('Data scientist details 0.csv',index_col = 0)
df_detail2 = pd.read_csv('Data scientist details 1058.csv',index_col = 0)
df_detail3 = pd.read_csv('Data scientist details 1531.csv',index_col = 0)
df_detail4 = pd.read_csv('Data scientist details 2528.csv',index_col = 0)
df_detail5 = pd.read_csv('Data scientist details 3546.csv',index_col = 0)
df_detail6 = pd.read_csv('Data scientist details 4300.csv',index_col = 0)

# %%
df = pd.concat([df_detail1, df_detail2,df_detail3, df_detail4, df_detail5, df_detail6], ignore_index=True)
df
# Out:
#                                                     url  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3     https://www.indeed.com/company/Pri-Global-Inc/...
# 4     https://www.indeed.com/rc/clk?jk=56c53f54d6307...
# ...                                                 ...
# 4386  https://www.indeed.com/rc/clk?jk=cad2933840fed...
# 4387  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4388  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4389  https://www.indeed.com/rc/clk?jk=4f7fb72171981...
# 4390  https://www.indeed.com/rc/clk?jk=7a27274a9388e...
#
#                        Job Type  \
# 0                 ['Full-time']
# 1     ['Full-time', 'Contract']
# 2     ['Full-time', 'Contract']
# 3     ['Full-time', 'Contract']
# 4                           NaN
# ...                         ...
# 4386              ['Full-time']
# ...

# %%
# Qualification analysis
df[~df['Qualifications'].isna()]
# Out:
#                                                     url  \
# 1     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3     https://www.indeed.com/company/Pri-Global-Inc/...
# 9     https://www.indeed.com/company/Gauss-Labs-Inc/...
# 16    https://www.indeed.com/company/Neal-Analytics/...
# ...                                                 ...
# 3940  https://www.indeed.com/company/SageBeans/jobs/...
# 3945  https://www.indeed.com/company/SageBeans/jobs/...
# 3950  https://www.indeed.com/company/SageBeans/jobs/...
# 4175  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4347  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                        Job Type  \
# 1     ['Full-time', 'Contract']
# 2     ['Full-time', 'Contract']
# 3     ['Full-time', 'Contract']
# 9                 ['Full-time']
# 16    ['Full-time', 'Contract']
# ...                         ...
# 3940              ['Full-time']
# ...

# %%
# Salary analysis
df_Salary = df[~df['Salary'].isna()]
df_Salary
# Out:
#                                                     url  \
# 1     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3     https://www.indeed.com/company/Pri-Global-Inc/...
# 9     https://www.indeed.com/company/Gauss-Labs-Inc/...
# 11    https://www.indeed.com/rc/clk?jk=5bd78c3877ca2...
# ...                                                 ...
# 4097  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4098  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4133  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4138  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4347  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                        Job Type  \
# 1     ['Full-time', 'Contract']
# 2     ['Full-time', 'Contract']
# 3     ['Full-time', 'Contract']
# 9                 ['Full-time']
# 11                ['Full-time']
# ...                         ...
# 4097              ['Full-time']
# ...
